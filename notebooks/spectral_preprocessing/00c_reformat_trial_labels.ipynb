# %% [markdown]
# # Add trial labels

# %% [markdown]
# Brief 1-2 sentence description of notebook.

# %%
import os
import glob
import git
import sys

# %%
# Imports of all used packages and libraries
import numpy as np
import pandas as pd
# import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import h5py
from scipy.interpolate import interp1d
from scipy.signal import savgol_filter

# %%
git_repo = git.Repo(".", search_parent_directories=True)
git_root = git_repo.git.rev_parse("--show-toplevel")

# %%
git_root
# Out:
# '/blue/npadillacoreano/ryoi360/projects/reward_comp/repos/reward_competition_extention'

# %%
sys.path.insert(0, os.path.join(git_root, 'src'))

# %%
# sns.set('notebook', 'ticks', font_scale=1.2)
mpl.rcParams['figure.figsize'] = [15,6]

# %% [markdown]
# ## Functions

# %% [markdown]
# ## Inputs & Data

# %% [markdown]
# Explanation of each input and where it comes from.

# %% [markdown]
# ## Outputs

# %% [markdown]
# Describe each output that the notebook creates.

# %% [markdown]
# - Is it a plot or is it data?

# %% [markdown]
# - How valuable is the output and why is it valuable or useful?

# %%
# Inputs and Required data loading
# input varaible names are in all caps snake case
# Whenever an input changes or is used for processing 
# the vairables are all lower in snake case
OUTPUT_DIR = r"./proc/" # where data is saved should always be shown in the inputs
os.makedirs(OUTPUT_DIR, exist_ok=True)
OUTPUT_PREFIX = "rce_pilot_2"

# %%
FULL_LFP_TRACES_PKL = "{}_03_spectral_trial_labels.pkl".format(OUTPUT_PREFIX)

# %% [markdown]
# ## Processing

# %% [markdown]
# ### Looking at when each subject was in each video

# %%
subject_start_stop_frames = pd.read_excel("./data/rce_per_subject_start_stop_video_frame.xlsx")
subject_start_stop_frames = subject_start_stop_frames.dropna(subset=["file_path"])

# %% [markdown]
# - Getting the name of the SLEAP and video files where each subject was in

# %%
subject_start_stop_frames["sleap_name"] = subject_start_stop_frames["file_path"].apply(lambda x: os.path.basename(x))
subject_start_stop_frames["video_name"] = subject_start_stop_frames["file_path"].apply(lambda x: ".".join(os.path.basename(x).split(".")[:2]))
subject_start_stop_frames["start_frame"] = subject_start_stop_frames["start_frame"].astype(int)
subject_start_stop_frames["stop_frame"] = subject_start_stop_frames["stop_frame"].astype(int)

# %%
subject_start_stop_frames = subject_start_stop_frames.drop(columns=["file_path", "notes", "in_video_subjects"], errors="ignore")

# %%
subject_start_stop_frames["video_name"].unique()
# Out:
# array(['20221214_125409_om_and_comp_6_1_and_6_3.1',
#        '20221215_145401_comp_amd_om_6_1_and_6_3.1',
#        '20230612_112630_standard_comp_to_training_D1_subj_1-2_and_1-1.1',
#        '20230612_112630_standard_comp_to_training_D1_subj_1-2_and_1-1.2',
#        '20230613_105657_standard_comp_to_training_D2_subj_1-1_and_1-4.1',
#        '20230613_105657_standard_comp_to_training_D2_subj_1-1_and_1-4.2',
#        '20230614_114041_standard_comp_to_training_D3_subj_1-1_and_1-2.1',
#        '20230614_114041_standard_comp_to_training_D3_subj_1-1_and_1-2.2',
#        '20230614_114041_standard_comp_to_training_D3_subj_1-1_and_1-2.3',
#        '20230616_111904_standard_comp_to_training_D4_subj_1-4_and_1-2.1',
#        '20230616_111904_standard_comp_to_training_D4_subj_1-4_and_1-2.2',
#        '20230617_115521_standard_comp_to_omission_D1_subj_1-1_and_1-2.1',
#        '20230617_115521_standard_comp_to_omission_D1_subj_1-1_and_1-2.3',
#        '20230618_100636_standard_comp_to_omission_D2_subj_1-4_and_1-1.1',
#        '20230618_100636_standard_comp_to_omission_D2_subj_1-4_and_1-1.2',
#        '20230619_115321_standard_comp_to_omission_D3_subj_1-2_and_1-4.3',
#        '20230619_115321_standard_comp_to_omission_D3_subj_1-2_and_1-4.4',
#        '20230620_114347_standard_comp_to_omission_D4_subj_1-2_and_1-1.1',
#        '20230620_114347_standard_comp_to_omission_D4_subj_1-2_and_1-1.2',
#        '20230621_111240_standard_comp_to_omission_D5_subj_1-4_and_1-2.1',
#        '20230621_111240_standard_comp_to_omission_D5_subj_1-4_and_1-2.2',
#        '20230622_110832_standard_comp_to_both_rewarded_D1_subj_1-1_and_1-2.1',
#        '20230623_114932_standard_comp_to_both_rewarded_D2_subj_1-4_and_1-1.1',
#        '20230623_114932_standard_comp_to_both_rewarded_D2_subj_1-4_and_1-1.2',
#        '20230624_105855_standard_comp_to_both_rewarded_D3_subj_1-2_and_1-4.1',
#        '20230625_112913_standard_comp_to_both_rewarded_D4_subj_1-1_and_1-4.1',
#        '20230628_111202_standard_comp_to_novel_agent_D1_subj_1-1vs2-2and1-2vs2-1.1',
#        '20230628_111202_standard_comp_to_novel_agent_D1_subj_1-1vs2-2and1-2vs2-1.2',
#        '20230628_111202_standard_comp_to_novel_agent_D1_subj_1-1vs2-2and1-2vs2-1.3',
#        '20230628_111202_standard_comp_to_novel_agent_D1_subj_1-1vs2-2and1-2vs2-1.4',
#        '20230629_111937_standard_comp_to_novel_agent_D2_subj_1-1vs2-1and1-4vs2-2.1',
#        '20230629_111937_standard_comp_to_novel_agent_D2_subj_1-1vs2-1and1-4vs2-2.2',
#        '20230630_115506_standard_comp_to_novel_agent_D3_subj_1-4vs2-1and1-2vs2-2.1',
#        '20230630_115506_standard_comp_to_novel_agent_D3_subj_1-4vs2-1and1-2vs2-2.2'],
#       dtype=object)

# %%
subject_start_stop_frames.head()
# Out:
#    start_frame  stop_frame tracked_subject  box_number  \
# 0            1       25000             6.3           1
# 1        27500       73600         6.1_6.3           1
# 2        51500       76454             6.3           1
# 3            1       48500         6.1_6.3           1
# 4        32700       68257             1.2           1
#
#                                           sleap_name  \
# 0  20221214_125409_om_and_comp_6_1_and_6_3.1.1_su...
# 1  20221214_125409_om_and_comp_6_1_and_6_3.1.2_su...
# 2  20221215_145401_comp_amd_om_6_1_and_6_3.1.1_su...
# 3  20221215_145401_comp_amd_om_6_1_and_6_3.1.2_su...
# 4  20230612_112630_standard_comp_to_training_D1_s...
#
#                                           video_name
# 0          20221214_125409_om_and_comp_6_1_and_6_3.1
# 1          20221214_125409_om_and_comp_6_1_and_6_3.1
# 2          20221215_145401_comp_amd_om_6_1_and_6_3.1
# 3          20221215_145401_comp_amd_om_6_1_and_6_3.1
# 4  20230612_112630_standard_comp_to_training_D1_s...

# %% [markdown]
# - Splitting each row into seperate row for each subject in the video

# %%
subject_start_stop_frames["current_subject"] = subject_start_stop_frames["tracked_subject"].apply(lambda x: str(x).split("_"))

# %%
subject_start_stop_frames = subject_start_stop_frames.explode("current_subject")

# %%
subject_start_stop_frames.head()
# Out:
#    start_frame  stop_frame tracked_subject  box_number  \
# 0            1       25000             6.3           1
# 1        27500       73600         6.1_6.3           1
# 1        27500       73600         6.1_6.3           1
# 2        51500       76454             6.3           1
# 3            1       48500         6.1_6.3           1
#
#                                           sleap_name  \
# 0  20221214_125409_om_and_comp_6_1_and_6_3.1.1_su...
# 1  20221214_125409_om_and_comp_6_1_and_6_3.1.2_su...
# 1  20221214_125409_om_and_comp_6_1_and_6_3.1.2_su...
# 2  20221215_145401_comp_amd_om_6_1_and_6_3.1.1_su...
# 3  20221215_145401_comp_amd_om_6_1_and_6_3.1.2_su...
#
#                                   video_name current_subject
# 0  20221214_125409_om_and_comp_6_1_and_6_3.1             6.3
# 1  20221214_125409_om_and_comp_6_1_and_6_3.1             6.1
# 1  20221214_125409_om_and_comp_6_1_and_6_3.1             6.3
# 2  20221215_145401_comp_amd_om_6_1_and_6_3.1             6.3
# 3  20221215_145401_comp_amd_om_6_1_and_6_3.1             6.1

# %% [markdown]
# ### Loading in trial labels

# %%
TRIAL_LABELS_DF = pd.read_excel("./data/rce_pilot_2_per_video_trial_labels.xlsx")
TRIAL_LABELS_DF = TRIAL_LABELS_DF.rename(columns={col: col.strip().lower() for col in TRIAL_LABELS_DF.columns})
TRIAL_LABELS_DF = TRIAL_LABELS_DF.dropna(subset=["condition"])

# %%
TRIAL_LABELS_DF = TRIAL_LABELS_DF.drop(columns=[col for col in TRIAL_LABELS_DF.columns if "unnamed" in col], errors="ignore")
TRIAL_LABELS_DF = TRIAL_LABELS_DF.drop(columns=[col for col in TRIAL_LABELS_DF.columns if "box" in col], errors="ignore")

# %% [markdown]
# - fixing up the data types of the labels

# %%
TRIAL_LABELS_DF["tone_start_timestamp"] = TRIAL_LABELS_DF["tone_start_timestamp"].astype(np.int64)
TRIAL_LABELS_DF["tone_stop_timestamp"] = TRIAL_LABELS_DF["tone_stop_timestamp"].astype(np.int64)
TRIAL_LABELS_DF["video_name"] = TRIAL_LABELS_DF["video_name"].apply(lambda x: ".".join(os.path.basename(x).split(".")[:2]))
TRIAL_LABELS_DF["tone_start_frame"] = TRIAL_LABELS_DF["tone_start_frame"].astype(int)
TRIAL_LABELS_DF["reward_start_frame"] = TRIAL_LABELS_DF["reward_start_frame"].astype(int)
TRIAL_LABELS_DF["tone_stop_frame"] = TRIAL_LABELS_DF["tone_stop_frame"].astype(int)

# %%
TRIAL_LABELS_DF.head()
# Out:
#                                           video_name  tone_start_frame  \
# 1  20230612_101430_standard_comp_to_training_D1_s...               980
# 2  20230612_101430_standard_comp_to_training_D1_s...              3376
# 3  20230612_101430_standard_comp_to_training_D1_s...              5672
# 4  20230612_101430_standard_comp_to_training_D1_s...              7468
# 5  20230612_101430_standard_comp_to_training_D1_s...              8566
#
#    reward_start_frame  tone_stop_frame condition competition_closeness notes  \
# 1                1080             1181       1.4           Subj 2 Only   NaN
# 2                3476             3575       1.3           Subj 1 Only   NaN
# 3                5772             5871       1.4           Subj 2 Only   NaN
# 4                7568             7668       1.4           Subj 2 Only   NaN
# 5                8666             8765       1.4           Subj 2 Only   NaN
#
#   experiment                                        session_dir  \
# 1   standard  20230612_101430_standard_comp_to_training_D1_s...
# 2   standard  20230612_101430_standard_comp_to_training_D1_s...
# 3   standard  20230612_101430_standard_comp_to_training_D1_s...
# 4   standard  20230612_101430_standard_comp_to_training_D1_s...
# 5   standard  20230612_101430_standard_comp_to_training_D1_s...
#
#      all_subjects  first_timestamp  last_timestamp  tone_start_timestamp  \
# 1  ['1.3', '1.4']        8798886.0      77093151.0                982229
# 2  ['1.3', '1.4']        8798886.0      77093151.0               3382227
# 3  ['1.3', '1.4']        8798886.0      77093151.0               5682225
# 4  ['1.3', '1.4']        8798886.0      77093151.0               7482224
# 5  ['1.3', '1.4']        8798886.0      77093151.0               8582220
#
#    tone_stop_timestamp
# 1              1182226
# 2              3582224
# 3              5882222
# 4              7682221
# 5              8782223

# %% [markdown]
# - Putting the dataframes together based on shared video name

# %%
merged_df = pd.merge(subject_start_stop_frames, TRIAL_LABELS_DF, on="video_name", how="inner")
merged_df = merged_df.dropna(subset=["current_subject"])

# %%
merged_df.head()
# Out:
#    start_frame  stop_frame tracked_subject  box_number  \
# 0        32700       68257             1.2           1
# 1        32700       68257             1.2           1
# 2        32700       68257             1.2           1
# 3        32700       68257             1.2           1
# 4        32700       68257             1.2           1
#
#                                           sleap_name  \
# 0  20230612_112630_standard_comp_to_training_D1_s...
# 1  20230612_112630_standard_comp_to_training_D1_s...
# 2  20230612_112630_standard_comp_to_training_D1_s...
# 3  20230612_112630_standard_comp_to_training_D1_s...
# 4  20230612_112630_standard_comp_to_training_D1_s...
#
#                                           video_name current_subject  \
# 0  20230612_112630_standard_comp_to_training_D1_s...             1.2
# 1  20230612_112630_standard_comp_to_training_D1_s...             1.2
# 2  20230612_112630_standard_comp_to_training_D1_s...             1.2
# 3  20230612_112630_standard_comp_to_training_D1_s...             1.2
# 4  20230612_112630_standard_comp_to_training_D1_s...             1.2
#
#    tone_start_frame  reward_start_frame  tone_stop_frame condition  \
# 0              1125                1225             1324       1.1
# 1              3519                3619             3720       1.2
# 2              5815                5915             6014       1.2
# 3              7612                7712             7811       1.2
# 4              8709                8809             8910       1.2
#
#     competition_closeness notes experiment  \
# 0  Subj 1 blocking Subj 2   NaN   standard
# 1             Subj 2 Only   NaN   standard
# 2  Subj 2 blocking Subj 1   NaN   standard
# 3             Subj 2 Only   NaN   standard
# 4             Subj 2 Only   NaN   standard
#
#                                          session_dir    all_subjects  \
# 0  20230612_112630_standard_comp_to_training_D1_s...  ['1.1', '1.2']
# 1  20230612_112630_standard_comp_to_training_D1_s...  ['1.1', '1.2']
# 2  20230612_112630_standard_comp_to_training_D1_s...  ['1.1', '1.2']
# 3  20230612_112630_standard_comp_to_training_D1_s...  ['1.1', '1.2']
# 4  20230612_112630_standard_comp_to_training_D1_s...  ['1.1', '1.2']
#
#    first_timestamp  last_timestamp  tone_start_timestamp  tone_stop_timestamp
# 0        7977066.0      76318450.0               1126742              1326741
# 1        7977066.0      76318450.0               3526740              3726740
# 2        7977066.0      76318450.0               5826740              6026737
# 3        7977066.0      76318450.0               7626736              7826735
# 4        7977066.0      76318450.0               8726734              8926734

# %% [markdown]
# - Filtering all trials rows that are not in the video

# %%
merged_df = merged_df[(merged_df['tone_start_frame'] > merged_df['start_frame']) & (merged_df['tone_start_frame'] < merged_df['stop_frame'])]

# %%
merged_df.head()
# Out:
#     start_frame  stop_frame tracked_subject  box_number  \
# 20        32700       68257             1.2           1
# 21        32700       68257             1.2           1
# 22        32700       68257             1.2           1
# 23        32700       68257             1.2           1
# 24        32700       68257             1.2           1
#
#                                            sleap_name  \
# 20  20230612_112630_standard_comp_to_training_D1_s...
# 21  20230612_112630_standard_comp_to_training_D1_s...
# 22  20230612_112630_standard_comp_to_training_D1_s...
# 23  20230612_112630_standard_comp_to_training_D1_s...
# 24  20230612_112630_standard_comp_to_training_D1_s...
#
#                                            video_name current_subject  \
# 20  20230612_112630_standard_comp_to_training_D1_s...             1.2
# 21  20230612_112630_standard_comp_to_training_D1_s...             1.2
# 22  20230612_112630_standard_comp_to_training_D1_s...             1.2
# 23  20230612_112630_standard_comp_to_training_D1_s...             1.2
# 24  20230612_112630_standard_comp_to_training_D1_s...             1.2
#
#     tone_start_frame  reward_start_frame  tone_stop_frame condition  \
# 20             37101               37201            37300  rewarded
# 21             38299               38399            38498  rewarded
# 22             39397               39497            39597  rewarded
# 23             40695               40795            40894  rewarded
# 24             41792               41892            41992  rewarded
#
#    competition_closeness notes experiment  \
# 20                   NaN   NaN   standard
# 21                   NaN   NaN   standard
# 22                   NaN   NaN   standard
# 23                   NaN   NaN   standard
# 24                   NaN   NaN   standard
#
#                                           session_dir    all_subjects  \
# 20  20230612_112630_standard_comp_to_training_D1_s...  ['1.1', '1.2']
# 21  20230612_112630_standard_comp_to_training_D1_s...  ['1.1', '1.2']
# 22  20230612_112630_standard_comp_to_training_D1_s...  ['1.1', '1.2']
# 23  20230612_112630_standard_comp_to_training_D1_s...  ['1.1', '1.2']
# 24  20230612_112630_standard_comp_to_training_D1_s...  ['1.1', '1.2']
#
#     first_timestamp  last_timestamp  tone_start_timestamp  tone_stop_timestamp
# 20        7977066.0      76318450.0              37126704             37326704
# 21        7977066.0      76318450.0              38326703             38526703
# 22        7977066.0      76318450.0              39426702             39626701
# 23        7977066.0      76318450.0              40726701             40926700
# 24        7977066.0      76318450.0              41826697             42026699

# %% [markdown]
# - Removing unnecssary columns

# %%
merged_df = merged_df.drop(columns=["start_frame", "stop_frame"], errors="ignore")
merged_df = merged_df.drop(columns=["first_timestamp", "last_timestamp"], errors="ignore")
merged_df = merged_df.drop(columns=["box_1_port_entry_frames", "box_2_port_entry_frames"], errors="ignore")
merged_df = merged_df.drop(columns=['box_1_port_entry_timestamps', 'box_2_port_entry_timestamps'], errors="ignore")

# %%
merged_df = merged_df.sort_values(by=["session_dir", "tone_start_timestamp", "video_name"]).reset_index(drop=True)

# %%
merged_df.head()
# Out:
#   tracked_subject  box_number  \
# 0         1.1_1.2           1
# 1         1.1_1.2           1
# 2         1.1_1.2           1
# 3         1.1_1.2           1
# 4         1.1_1.2           1
#
#                                           sleap_name  \
# 0  20230612_112630_standard_comp_to_training_D1_s...
# 1  20230612_112630_standard_comp_to_training_D1_s...
# 2  20230612_112630_standard_comp_to_training_D1_s...
# 3  20230612_112630_standard_comp_to_training_D1_s...
# 4  20230612_112630_standard_comp_to_training_D1_s...
#
#                                           video_name current_subject  \
# 0  20230612_112630_standard_comp_to_training_D1_s...             1.1
# 1  20230612_112630_standard_comp_to_training_D1_s...             1.2
# 2  20230612_112630_standard_comp_to_training_D1_s...             1.1
# 3  20230612_112630_standard_comp_to_training_D1_s...             1.2
# 4  20230612_112630_standard_comp_to_training_D1_s...             1.1
#
#    tone_start_frame  reward_start_frame  tone_stop_frame condition  \
# 0              1125                1225             1324       1.1
# 1              1125                1225             1324       1.1
# 2              3519                3619             3720       1.2
# 3              3519                3619             3720       1.2
# 4              5815                5915             6014       1.2
#
#     competition_closeness notes experiment  \
# 0  Subj 1 blocking Subj 2   NaN   standard
# 1  Subj 1 blocking Subj 2   NaN   standard
# 2             Subj 2 Only   NaN   standard
# 3             Subj 2 Only   NaN   standard
# 4  Subj 2 blocking Subj 1   NaN   standard
#
#                                          session_dir    all_subjects  \
# 0  20230612_112630_standard_comp_to_training_D1_s...  ['1.1', '1.2']
# 1  20230612_112630_standard_comp_to_training_D1_s...  ['1.1', '1.2']
# 2  20230612_112630_standard_comp_to_training_D1_s...  ['1.1', '1.2']
# 3  20230612_112630_standard_comp_to_training_D1_s...  ['1.1', '1.2']
# 4  20230612_112630_standard_comp_to_training_D1_s...  ['1.1', '1.2']
#
#    tone_start_timestamp  tone_stop_timestamp
# 0               1126742              1326741
# 1               1126742              1326741
# 2               3526740              3726740
# 3               3526740              3726740
# 4               5826740              6026737

# %% [markdown]
# ## Adding competition labels

# %%
non_competitive_labels = ['rewarded', 'omission', 'both_rewarded']

# %%
merged_df["current_subject"] = merged_df["current_subject"].astype(str)
merged_df["condition"] = merged_df["condition"].astype(str)

# %%
merged_df["tracked_subject"] = merged_df["tracked_subject"].astype(str).apply(lambda x: x.split("_"))

# %%
merged_df["trial_label"] = merged_df.apply(lambda x: x["condition"] if x["condition"] in non_competitive_labels else ("win" if x["condition"] == x["current_subject"] else "lose"), axis=1)

# %%
merged_df.head()
# Out:
#   tracked_subject  box_number  \
# 0      [1.1, 1.2]           1
# 1      [1.1, 1.2]           1
# 2      [1.1, 1.2]           1
# 3      [1.1, 1.2]           1
# 4      [1.1, 1.2]           1
#
#                                           sleap_name  \
# 0  20230612_112630_standard_comp_to_training_D1_s...
# 1  20230612_112630_standard_comp_to_training_D1_s...
# 2  20230612_112630_standard_comp_to_training_D1_s...
# 3  20230612_112630_standard_comp_to_training_D1_s...
# 4  20230612_112630_standard_comp_to_training_D1_s...
#
#                                           video_name current_subject  \
# 0  20230612_112630_standard_comp_to_training_D1_s...             1.1
# 1  20230612_112630_standard_comp_to_training_D1_s...             1.2
# 2  20230612_112630_standard_comp_to_training_D1_s...             1.1
# 3  20230612_112630_standard_comp_to_training_D1_s...             1.2
# 4  20230612_112630_standard_comp_to_training_D1_s...             1.1
#
#    tone_start_frame  reward_start_frame  tone_stop_frame condition  \
# 0              1125                1225             1324       1.1
# 1              1125                1225             1324       1.1
# 2              3519                3619             3720       1.2
# 3              3519                3619             3720       1.2
# 4              5815                5915             6014       1.2
#
#     competition_closeness notes experiment  \
# 0  Subj 1 blocking Subj 2   NaN   standard
# 1  Subj 1 blocking Subj 2   NaN   standard
# 2             Subj 2 Only   NaN   standard
# 3             Subj 2 Only   NaN   standard
# 4  Subj 2 blocking Subj 1   NaN   standard
#
#                                          session_dir    all_subjects  \
# 0  20230612_112630_standard_comp_to_training_D1_s...  ['1.1', '1.2']
# 1  20230612_112630_standard_comp_to_training_D1_s...  ['1.1', '1.2']
# 2  20230612_112630_standard_comp_to_training_D1_s...  ['1.1', '1.2']
# 3  20230612_112630_standard_comp_to_training_D1_s...  ['1.1', '1.2']
# 4  20230612_112630_standard_comp_to_training_D1_s...  ['1.1', '1.2']
#
#    tone_start_timestamp  tone_stop_timestamp trial_label
# 0               1126742              1326741         win
# 1               1126742              1326741        lose
# 2               3526740              3726740        lose
# 3               3526740              3726740         win
# 4               5826740              6026737        lose

# %%
merged_df.tail()
# Out:
#      tracked_subject  box_number  \
# 1258      [1.2, 2.2]           2
# 1259      [1.4, 2.1]           1
# 1260      [1.4, 2.1]           1
# 1261      [1.2, 2.2]           2
# 1262      [1.2, 2.2]           2
#
#                                              sleap_name  \
# 1258  20230630_115506_standard_comp_to_novel_agent_D...
# 1259  20230630_115506_standard_comp_to_novel_agent_D...
# 1260  20230630_115506_standard_comp_to_novel_agent_D...
# 1261  20230630_115506_standard_comp_to_novel_agent_D...
# 1262  20230630_115506_standard_comp_to_novel_agent_D...
#
#                                              video_name current_subject  \
# 1258  20230630_115506_standard_comp_to_novel_agent_D...             2.2
# 1259  20230630_115506_standard_comp_to_novel_agent_D...             1.4
# 1260  20230630_115506_standard_comp_to_novel_agent_D...             2.1
# 1261  20230630_115506_standard_comp_to_novel_agent_D...             1.2
# 1262  20230630_115506_standard_comp_to_novel_agent_D...             2.2
#
#       tone_start_frame  reward_start_frame  tone_stop_frame condition  \
# 1258             66104               66204            66303       2.2
# 1259             68460               68560            68660       2.1
# 1260             68460               68560            68660       2.1
# 1261             67102               67202            67301       2.2
# 1262             67102               67202            67301       2.2
#
#      competition_closeness                                              notes  \
# 1258           After trial  2.2 Chase or bite 1.4 then grab after trial is...
# 1259    Subj 2 then Subj 1                                                NaN
# 1260    Subj 2 then Subj 1                                                NaN
# 1261           After trial  2.2 Chase or bite 1.4 then grab after trial is...
# 1262           After trial  2.2 Chase or bite 1.4 then grab after trial is...
#
#      experiment                                        session_dir  \
# 1258      novel  20230630_115506_standard_comp_to_novel_agent_D...
# 1259      novel  20230630_115506_standard_comp_to_novel_agent_D...
# 1260      novel  20230630_115506_standard_comp_to_novel_agent_D...
# 1261      novel  20230630_115506_standard_comp_to_novel_agent_D...
# 1262      novel  20230630_115506_standard_comp_to_novel_agent_D...
#
#                       all_subjects  tone_start_timestamp  tone_stop_timestamp  \
# 1258  ['1.2', '1.4', '2.1', '2.2']              66073522             66273524
# 1259  ['1.2', '1.4', '2.1', '2.2']              67073535             67273537
# 1260  ['1.2', '1.4', '2.1', '2.2']              67073535             67273537
# 1261  ['1.2', '1.4', '2.1', '2.2']              67073535             67273537
# 1262  ['1.2', '1.4', '2.1', '2.2']              67073535             67273537
#
#      trial_label
# 1258         win
# 1259        lose
# 1260         win
# 1261        lose
# 1262         win

# %%
merged_df.to_excel("./proc/rce2_finalized_trial_labels.xlsx", index=False)

# %%
merged_df.to_pickle("./proc/rce2_finalized_trial_labels.pkl")

# %%
raise ValueError()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 raise ValueError()
#
# ValueError:
